# %% [markdown]
# # Colab Git Demo Notebook

# %%
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/colab_git_demo")

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/colab_git_demo

# %%
# !ls
# Out:
# main.ipynb

# %%
# Initialising an empty repository
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/colab_git_demo/.git/

# %%
# Add your email to the global config-file
# !git config --global user.email "lorenzo_stamaria@yahoo.com"

# %%
# Add your username to the global config-file
# !git config --global user.name "Lorenzo Sta. Maria"

# %%
# . is to add all the files. You can selectively select the files you can add too
# by mentioning the file names
# !git add .

# %%
# Commiting the added files and writing a commit message along with it
# !git commit -m "New Commit"
# Out:
# [master 4a0fe6e] New Commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite main.ipynb (94%)

# %%
# !git remote set-url origin

# %%
# # Adding your remote repository into your colab system
# !git remote add origin https://lstamaria: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@github.com/lstamaria/colab_git_demo.git

# %%
# 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
# Update your remote repository into your colab system
# !git remote set-url origin https://lstamaria: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@github.com/lstamaria/colab_git_demo.git

# %%
# # To push the committed files into your repository
# !git push -u https://lstamaria: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@github.com/lstamaria/colab_git_demo.git --all --force

# %%
# # To push the committed files into your repository
# !git push -u origin master
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 1.26 KiB | 257.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/lstamaria/colab_git_demo.git
#    3e9c51c..4a0fe6e  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# !git remote -v
# Out:
# origin	https://lstamaria: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@github.com/lstamaria/colab_git_demo.git (fetch)
# origin	https://lstamaria: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@github.com/lstamaria/colab_git_demo.git (push)

# %%
# !git checkout master   
# !git branch main master -f    
# !git checkout main  
git push origin main -f
